# %%
import pandas as pd
import mlxtend
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import xlrd
df = pd.read_excel('http://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# %%
basket = (df[df['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)
basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.head()
# Out:
#                                          antecedents  \
# 0  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 1  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 2  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 3                      (SET/6 RED SPOTTY PAPER CUPS)
# 4               (SET/20 RED RETROSPOT PAPER NAPKINS)
#
#                                          consequents  antecedent support  \
# 0                    (SET/6 RED SPOTTY PAPER PLATES)            0.102041
# 1               (SET/20 RED RETROSPOT PAPER NAPKINS)            0.122449
# 2                      (SET/6 RED SPOTTY PAPER CUPS)            0.102041
# 3  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.137755
# 4  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...            0.132653
#
#    consequent support  support  confidence      lift  leverage  conviction
# 0            0.127551  0.09949    0.975000  7.644000  0.086474   34.897959
# 1            0.132653  0.09949    0.812500  6.125000  0.083247    4.625850
# 2            0.137755  0.09949    0.975000  7.077778  0.085433   34.489796
# 3            0.102041  0.09949    0.722222  7.077778  0.085433    3.232653
# 4            0.122449  0.09949    0.750000  6.125000  0.083247    3.510204

# %%
rules[ (rules['lift'] >= 6) &
       (rules['confidence'] >= 0.8) ]
# Out:
#                                           antecedents  \
# 0   (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 1   (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 2   (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 6                        (ALARM CLOCK BAKELIKE GREEN)
# 7                          (ALARM CLOCK BAKELIKE RED)
# 10                      (SET/6 RED SPOTTY PAPER CUPS)
# 11                    (SET/6 RED SPOTTY PAPER PLATES)
# 15                    (SET/6 RED SPOTTY PAPER PLATES)
#
#                              consequents  antecedent support  \
# 0        (SET/6 RED SPOTTY PAPER PLATES)            0.102041
# 1   (SET/20 RED RETROSPOT PAPER NAPKINS)            0.122449
# 2          (SET/6 RED SPOTTY PAPER CUPS)            0.102041
# 6             (ALARM CLOCK BAKELIKE RED)            0.096939
# 7           (ALARM CLOCK BAKELIKE GREEN)            0.094388
# 10       (SET/6 RED SPOTTY PAPER PLATES)            0.137755
# 11         (SET/6 RED SPOTTY PAPER CUPS)            0.127551
# 15  (SET/20 RED RETROSPOT PAPER NAPKINS)            0.127551
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.127551  0.099490    0.975000  7.644000  0.086474   34.897959
# 1             0.132653  0.099490    0.812500  6.125000  0.083247    4.625850
# 2             0.137755  0.099490    0.975000  7.077778  0.085433   34.489796
# 6             0.094388  0.079082    0.815789  8.642959  0.069932    4.916181
# 7             0.096939  0.079082    0.837838  8.642959  0.069932    5.568878
# 10            0.127551  0.122449    0.888889  6.968889  0.104878    7.852041
# 11            0.137755  0.122449    0.960000  6.968889  0.104878   21.556122
# 15            0.132653  0.102041    0.800000  6.030769  0.085121    4.336735

# %%
basket['ALARM CLOCK BAKELIKE GREEN'].sum()



basket['ALARM CLOCK BAKELIKE RED'].sum()
# Out:
# 316.0

# %%
basket2 = (df[df['Country'] =="Germany"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

basket_sets2 = basket2.applymap(encode_units)
basket_sets2.drop('POSTAGE', inplace=True, axis=1)
frequent_itemsets2 = apriori(basket_sets2, min_support=0.05, use_colnames=True)
rules2 = association_rules(frequent_itemsets2, metric="lift", min_threshold=1)

rules2[ (rules2['lift'] >= 4) &
        (rules2['confidence'] >= 0.5)]
# Out:
#                         antecedents                         consequents  \
# 7     (RED RETROSPOT CHARLOTTE BAG)            (WOODLAND CHARLOTTE BAG)
# 10  (PLASTERS IN TIN CIRCUS PARADE)  (PLASTERS IN TIN WOODLAND ANIMALS)
# 13       (PLASTERS IN TIN SPACEBOY)  (PLASTERS IN TIN WOODLAND ANIMALS)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 7             0.070022            0.126915  0.059081    0.843750  6.648168
# 10            0.115974            0.137856  0.067834    0.584906  4.242887
# 13            0.107221            0.137856  0.061269    0.571429  4.145125
#
#     leverage  conviction
# 7   0.050194    5.587746
# 10  0.051846    2.076984
# 13  0.046488    2.011670

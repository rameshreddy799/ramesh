# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

df = pd.read_csv('C:\\Users\\ashishranjan\\Downloads\\Iris.csv')

# %%
df.isnull().any()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df['PetalWidthCm'].plot.hist()
plt.show()

# %%
sns.pairplot(df, hue='Species')

# %%
all_inputs = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']].values
all_classes = df['Species'].values

(train_inputs, test_inputs, train_classes, test_classes) = train_test_split(all_inputs, all_classes, train_size=0.7, random_state=1)
# Out:
# C:\Users\ashishranjan\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2010: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
dtc = DecisionTreeClassifier()
dtc.fit(train_inputs, train_classes)
dtc.score(test_inputs, test_classes)
# Out:
# 0.9555555555555556

# %%
predicted=dtc.predict(test_inputs)

# %%
import pandas_ml

# %%
from pandas_ml import ConfusionMatrix

# %%
ConfusionMatrix(test_classes,predicted)
# Out:
# Predicted        Iris-setosa  Iris-versicolor  Iris-virginica  __all__
# Actual
# Iris-setosa               14                0               0       14
# Iris-versicolor            0               17               1       18
# Iris-virginica             0                1              12       13
# __all__                   14               18              13       45

# %%
cm=ConfusionMatrix(test_classes,predicted)
cm.print_stats()
# Out:
# Confusion Matrix:
#
# Predicted        Iris-setosa  Iris-versicolor  Iris-virginica  __all__
# Actual
# Iris-setosa               14                0               0       14
# Iris-versicolor            0               17               1       18
# Iris-virginica             0                1              12       13
# __all__                   14               18              13       45
#
#
# Overall Statistics:
#
# Accuracy: 0.9555555555555556
# 95% CI: (0.8485070997566608, 0.9945715112997491)
# No Information Rate: ToDo
# P-Value [Acc > NIR]: 2.8423103301992384e-15
# Kappa: 0.9326347305389221
# Mcnemar's Test P-Value: ToDo
#
#
# Class Statistics:
#
# Classes                               Iris-setosa Iris-versicolor  \
# Population                                     45              45
# P: Condition positive                          14              18
# N: Condition negative                          31              27
# ...
